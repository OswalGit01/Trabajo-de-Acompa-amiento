# %% [markdown]
# <a href="https://colab.research.google.com/github/OswalGit01/Trabajo-de-Acompa-amiento/blob/main/PDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

df1= pd.read_csv("diabetes.csv")

print(df1.columns)
df1
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
import matplotlib.pyplot as plt

plt.title('Histograma Glucosa')
plt.hist(df1.Glucose, color='darkred', alpha=0.8, label='Glucosa')
plt.ylabel('Frecuencia', fontsize=10)
plt.xlabel('Glucosa', fontsize=10)
plt.grid(True)
plt.show()

# %%
plt.title('Histograma Insulina')
plt.hist(df1.Insulin,color='darkred',alpha=0.8  )
plt.ylabel('Frecuencia', fontsize=10)
plt.xlabel('Insulina', fontsize=10)
plt.grid(True)
plt.show()

# %%
plt.title('Histogram BloodPressure')
plt.hist(df1.BloodPressure,color='darkred',alpha=0.8)
plt.ylabel('Frecuencia', fontsize=10)
plt.xlabel('Presión Sanguinea', fontsize=10)
plt.grid()

# %%
df1["Pregnancies"].value_counts().plot(
    kind="bar",
    title="Pregnancies",
    color="darkred"
)

plt.xlabel("Numero de embarazos")
plt.ylabel("Cuenta")

plt.show()

# %%
df1["Outcome"].value_counts().plot(
    kind="bar",
    title="Diabetes",
    color='darkred'
)

plt.xlabel("¿Tiene diabetes?")
plt.ylabel("Cuenta")

plt.show()

# %%
df1["Outcome"].value_counts().plot(
    kind="pie",
    colors=["darkred", "darkorange"],
    title='Distribucion de la variable de salida',
    labels=["No Diabetes", "Diabetes"],
    ylabel=''
)
# Out:
# <Axes: title={'center': 'Distribucion de la variable de salida'}>

# %%
df1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
fig = plt.figure(figsize=(14,8))
sns.boxplot(data=df1)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df1,
    x="Glucose",
    y="Age",
    hue="Outcome",
    palette={0: "darkred", 1: "darkorange"},
    alpha=0.7,
    s=60
)

plt.title("Scatter Plot de glucosa vs edad por variable salida")
plt.xlabel("Glucosa")
plt.ylabel("Edad")

plt.legend(title="Variable salida", labels=["No Diabetes", "Diabetes"])

plt.show()
